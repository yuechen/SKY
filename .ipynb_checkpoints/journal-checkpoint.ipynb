# %%
# Description of process of pyGTrends construction

# %%
from gtrends import gtrends
import pandas as pd
import numpy as np

# %%
for i in range(1, 12):
    if i < 10:
        month = "0" + str(i)
    else:
        month = str(i)
    
    gtrends.getGoogleTrendData("apple", "apple_" + month + ".csv", "2013-" + month)
# Out:
# File saved: apple_01.csv
# File saved: apple_02.csv
# File saved: apple_03.csv
# File saved: apple_04.csv
# File saved: apple_05.csv
# File saved: apple_06.csv
# File saved: apple_07.csv
# File saved: apple_08.csv
# File saved: apple_09.csv
# File saved: apple_10.csv
# File saved: apple_11.csv

# %%
import yahoo_stock

# %%
prices = yahoo_stock.get_historical_prices('AAPL', '20130101', '20131201')
print prices
# Out:
# [['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Clos'], ['2013-11-29', '549.48', '558.33', '547.81', '556.07', '11361700', '556.0'], ['2013-11-27', '536.31', '546.00', '533.40', '545.96', '12980300', '545.9'], ['2013-11-26', '524.12', '536.14', '524.00', '533.40', '14335100', '533.4'], ['2013-11-25', '521.02', '525.87', '521.00', '523.74', '8189700', '523.7'], ['2013-11-22', '519.52', '522.16', '518.53', '519.80', '7990200', '519.8'], ['2013-11-21', '517.60', '521.21', '513.67', '521.14', '9358100', '521.1'], ['2013-11-20', '519.23', '520.42', '514.33', '515.00', '6925600', '515.0'], ['2013-11-19', '519.03', '523.38', '517.97', '519.55', '7462100', '519.5'], ['2013-11-18', '524.99', '527.19', '518.20', '518.63', '8748000', '518.6'], ['2013-11-15', '526.58', '529.09', '524.49', '524.99', '11354300', '524.9'], ['2013-11-14', '522.81', '529.28', '521.87', '528.16', '10086400', '528.1'], ['2013-11-13', '518.00', '522.25', '516.96', '520.63', '7043600', '520.6'], ['2013-11-12', '517.67', '523.92', '517.00', '520.01', '7295600', '520.0'], ['2013-11-11', '519.99', '521.67', '514.41', '519.05', '8123300', '519.0'], ['2013-11-08', '514.58', '521.13', '512.59', '520.56', '9975600', '520.5'], ['2013-11-07', '519.58', '523.19', '512.38', '512.49', '9379300', '512.4'], ['2013-11-06', '524.15', '524.86', '518.20', '520.92', '7977700', '520.9'], ['2013-11-05', '524.58', '528.89', '523.00', '525.45', '9471900', '522.4'], ['2013-11-04', '521.10', '526.82', '518.81', '526.75', '8736700', '523.6'], ['2013-11-01', '524.02', '524.80', '515.84', '520.03', '9817500', '517.0'], ['2013-10-31', '525.00', '527.49', '521.27', '522.70', '9846300', '519.6'], ['2013-10-30', '519.61', '527.52', '517.02', '524.90', '12648700', '521.8'], ['2013-10-29', '536.27', '539.25', '514.54', '516.68', '22707400', '513.6'], ['2013-10-28', '529.04', '531.00', '523.21', '529.88', '19658600', '526.8'], ['2013-10-25', '531.32', '533.23', '525.11', '525.96', '12064000', '522.9'], ['2013-10-24', '525.00', '532.47', '522.45', '531.91', '13741600', '528.8'], ['2013-10-23', '519.00', '525.67', '519.00', '524.96', '11204400', '521.9'], ['2013-10-22', '526.41', '528.45', '508.03', '519.87', '19073700', '516.8'], ['2013-10-21', '511.77', '524.30', '511.52', '521.36', '14218100', '518.3'], ['2013-10-18', '505.99', '509.26', '505.71', '508.89', '10376500', '505.9'], ['2013-10-17', '499.98', '504.78', '499.68', '504.50', '9056900', '501.5'], ['2013-10-16', '500.79', '502.53', '499.23', '501.11', '8967900', '498.2'], ['2013-10-15', '497.51', '502.00', '495.52', '498.68', '11431200', '495.7'], ['2013-10-14', '489.83', '497.58', '489.35', '496.04', '9353500', '493.1'], ['2013-10-11', '486.99', '493.84', '485.16', '492.81', '9562100', '489.9'], ['2013-10-10', '491.32', '492.38', '487.04', '489.64', '9950100', '486.8'], ['2013-10-09', '484.64', '487.79', '478.28', '486.59', '10775900', '483.7'], ['2013-10-08', '489.94', '490.64', '480.54', '480.94', '10389900', '478.1'], ['2013-10-07', '486.56', '492.65', '485.35', '487.75', '11153300', '484.9'], ['2013-10-04', '483.86', '484.60', '478.60', '483.03', '9245300', '480.2'], ['2013-10-03', '490.51', '492.35', '480.74', '483.41', '11526900', '480.6'], ['2013-10-02', '485.63', '491.80', '483.75', '489.56', '10328000', '486.7'], ['2013-10-01', '478.45', '489.14', '478.38', '487.96', '12638700', '485.1'], ['2013-09-30', '477.25', '481.66', '474.41', '476.75', '9291300', '473.9'], ['2013-09-27', '483.78', '484.67', '480.72', '482.75', '8144300', '479.9'], ['2013-09-26', '486.00', '488.56', '483.90', '486.22', '8472200', '483.4'], ['2013-09-25', '489.20', '489.64', '481.43', '481.53', '11319900', '478.7'], ['2013-09-24', '494.88', '495.47', '487.82', '489.10', '13012300', '486.2'], ['2013-09-23', '496.10', '496.91', '482.60', '490.64', '27218100', '487.7'], ['2013-09-20', '478.00', '478.55', '466.00', '467.41', '24975100', '464.7'], ['2013-09-19', '470.70', '475.83', '469.25', '472.30', '14447900', '469.5'], ['2013-09-18', '463.18', '466.35' ...

# %%
apple_gtrend = pd.DataFrame()

for i in range(1, 12):
    if i < 10:
        month = "0" + str(i)
    else:
        month = str(i)
    
    df = pd.DataFrame.from_csv('apple_' + month + '.csv')
    apple_gtrend = pd.concat([apple_gtrend, df])

apple_gtrend.head(60)
# Out:
#             apple
# 2013-01-01     94
# 2013-01-02    100
# 2013-01-03     89
# 2013-01-04     88
# 2013-01-05     89
# 2013-01-06     89
# 2013-01-07     82
# 2013-01-08     80
# 2013-01-09     77
# 2013-01-10     73
# 2013-01-11     74
# 2013-01-12     81
# 2013-01-13     81
# 2013-01-14     76
# 2013-01-15     76
# 2013-01-16     71
# 2013-01-17     71
# 2013-01-18     69
# 2013-01-19     77
# 2013-01-20     77
# 2013-01-21     70
# 2013-01-22     71
# 2013-01-23     75
# 2013-01-24     79
# 2013-01-25     78
# 2013-01-26     80
# 2013-01-27     80
# 2013-01-28     73
# 2013-01-29     77
# 2013-01-30     74
# 2013-01-31     73
# 2013-02-01     90
# 2013-02-02    100
# 2013-02-03     96
# 2013-02-04     92
# 2013-02-05     88
# 2013-02-06     88
# 2013-02-07     86
# 2013-02-08     89
# 2013-02-09     95
# 2013-02-10     97
# 2013-02-11     90
# 2013-02-12     88
# 2013-02-13     88
# 2013-02-14     87
# 2013-02-15     86
# 2013-02-16     94
# 2013-02-17     94
# 2013-02-18     87
# 2013-02-19     86
# 2013-02-20     90
# 2013-02-21     86
# 2013-02-22     86
# 2013-02-23     94
# 2013-02-24     93
# 2013-02-25     81
# 2013-02-26     82
# 2013-02-27     86
# 2013-02-28     84
# 2013-03-01     89

# %%
gtrends.getGoogleTrendData("apple iphone", "apple_iphone_year.csv", "1990")
# Out:
# File saved: apple_iphone_year.csv

# %%
gtrends.getGoogleTrendData("america", "america_year.csv", "1990")
# Out:
# File saved: america_year.csv

# %%
# Constructing the raw dataset from which we want to work
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
years = [str(y) for y in range(2004, 2014)]
companies = [('AAPL', 'apple'), ('FB', 'facebook'), ('YHOO', 'yahoo')]

all_company_data = pd.DataFrame()

for ticker, name in companies:
    stock_info = yahoo_stock.get_historical_prices(ticker, '20131101', '20131201')
    df = pd.DataFrame(stock_info[1:])
    df.columns = stock_info[0]
    df = df.set_index('Date')
    
    all_time_data = pd.DataFrame()
    for year in years:
        for month in months:
            date = year + '-' + month
            filename = "data/" + name + "_" + date + ".csv"
            gtrends.getGoogleTrendData(name, filename, date)
            month_data = pd.DataFrame.from_csv(filename)
            month_data.columns = ['Trend']
            
            all_time_data = pd.concat([all_time_data, month_data])

    df = df.join(all_time_data, how="outer")
    
    df['Ticker'] = pd.Series([ticker] * len(df), index=df.index)
    df = df.reset_index()
    new_columns = list(df.columns)
    new_columns[0] = 'Date'
    df.columns = new_columns
    df.Date = df.Date.apply(lambda d: d.strftime('%Y-%m-%d'))
    
    all_company_data = pd.concat([all_company_data, df])

all_company_data = all_company_data.reset_index()
del all_company_data['index']

# %%
all_company_data.head(60)
# Out:
#    Adj Clos   Close        Date    High     Low    Open Ticker  Trend    Volume
# 0     517.0  520.03  2013-11-01  524.80  515.84  524.02   AAPL     73   9817500
# 1       NaN     NaN  2013-11-02     NaN     NaN     NaN   AAPL     71       NaN
# 2       NaN     NaN  2013-11-03     NaN     NaN     NaN   AAPL     70       NaN
# 3     523.6  526.75  2013-11-04  526.82  518.81  521.10   AAPL     63   8736700
# 4     522.4  525.45  2013-11-05  528.89  523.00  524.58   AAPL     59   9471900
# 5     520.9  520.92  2013-11-06  524.86  518.20  524.15   AAPL     57   7977700
# 6     512.4  512.49  2013-11-07  523.19  512.38  519.58   AAPL     58   9379300
# 7     520.5  520.56  2013-11-08  521.13  512.59  514.58   AAPL     57   9975600
# 8       NaN     NaN  2013-11-09     NaN     NaN     NaN   AAPL     62       NaN
# 9       NaN     NaN  2013-11-10     NaN     NaN     NaN   AAPL     63       NaN
# 10    519.0  519.05  2013-11-11  521.67  514.41  519.99   AAPL     59   8123300
# 11    520.0  520.01  2013-11-12  523.92  517.00  517.67   AAPL     63   7295600
# 12    520.6  520.63  2013-11-13  522.25  516.96  518.00   AAPL     59   7043600
# 13    528.1  528.16  2013-11-14  529.28  521.87  522.81   AAPL     60  10086400
# 14    524.9  524.99  2013-11-15  529.09  524.49  526.58   AAPL     58  11354300
# 15      NaN     NaN  2013-11-16     NaN     NaN     NaN   AAPL     65       NaN
# 16      NaN     NaN  2013-11-17     NaN     NaN     NaN   AAPL     66       NaN
# 17    518.6  518.63  2013-11-18  527.19  518.20  524.99   AAPL     59   8748000
# 18    519.5  519.55  2013-11-19  523.38  517.97  519.03   AAPL     59   7462100
# 19    515.0  515.00  2013-11-20  520.42  514.33  519.23   AAPL     64   6925600
