# %%
# %matplotlib inline

from gtrends import gtrends
import pandas as pd
import numpy as np
import yahoo_stock

# %%
# Constructing the raw dataset from which we want to work
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
years = [str(y) for y in range(2004, 2014)]
companies = [('AAPL', 'apple'), ('FB', 'facebook'), ('YHOO', 'yahoo')]

ticker = 'AAPL'
name = 'apple'

stock_info = yahoo_stock.get_historical_prices(ticker, '20040101', '20131201')
df = pd.DataFrame(stock_info[1:])
df.columns = stock_info[0]
df = df.set_index('Date')

all_time_data = pd.DataFrame()
for year in years:
    for month in months:
        date = year + '-' + month
        filename = "data/" + name + "_" + date + ".csv"
        #gtrends.getGoogleTrendData(name, filename, date)
        month_data = pd.DataFrame.from_csv(filename)
        month_data.columns = ['Trend']
        
        all_time_data = pd.concat([all_time_data, month_data])

df = df.join(all_time_data, how="outer")

df['Ticker'] = pd.Series([ticker] * len(df), index=df.index)
df = df.reset_index()
new_columns = list(df.columns)
new_columns[0] = 'Date'
df.columns = new_columns
df.Date = df.Date.apply(lambda d: d.strftime('%Y-%m-%d'))

# %%
apple_complete_data = df

# %%
import math

last_weeks_prices = []
last_weeks_trends = []
apple_formatted_data = []
current_month = '01'
for key, row in (apple_complete_data[4:]).iterrows():
    if key % 7 == 4:
        stock_price = float(row['Open'])
        if len(last_weeks_prices) != 5 or len(last_weeks_trends != 7) or math.isnan(stock_price):
            last_weeks_prices = []
            last_weeks_trends = []
        else:
            last_weeks_data = []
            
            friday_price = last_weeks_prices[4]
            normalizing_price = last_weeks_prices[0]
            monday_price = (stock_price / normalizing_price) * 100
            last_weeks_prices = [(p / normalizing_price) * 100 for p in last_weeks_prices]
            
            max_trend = max(last_weeks_trends)
            last_weeks_trends = [(t / float(max_trend)) * 100 for t in last_weeks_trends]
            
            apple_formatted_data.append([monday_price] + last_weeks_prices + last_weeks_trends)
            last_weeks_prices = []
            last_weeks_trends = []
    
    stock_price = float(row['Open'])
    if not math.isnan(stock_price):
        last_weeks_prices.append(stock_price)
    if current_month == row['Date'][5:7]:
        last_weeks_trends.append(row['Trend'])

print apple_formatted_data
# Out:
# [[108.54341736694677, 100.0, 103.87488328664799, 103.17460317460316, 106.62931839402428, 108.4500466853408, 80.0, 100.0, 93.0, 92.0, 87.0, 91.0, 89.0], [100.0, 100.0, 102.58236865538734, 101.69189670525378, 100.75690115761353, 100.84594835262688, 89.77272727272727, 85.22727272727273, 87.5, 87.5, 92.04545454545455, 100.0, 94.31818181818183], [100.71237756010684, 100.0, 99.28762243989314, 97.95191451469279, 97.15048975957257, 99.95547640249332, 87.09677419354838, 77.41935483870968, 82.79569892473118, 81.72043010752688, 84.94623655913979, 100.0, 77.41935483870968], [107.87824529991047, 100.0, 99.1047448522829, 99.73142345568488, 102.41718889883617, 102.77529095792302, 79.0, 77.0, 76.0, 75.0, 76.0, 83.0, 100.0], [110.45643153526972, 100.0, 99.58506224066389, 97.9253112033195, 99.29460580912863, 103.52697095435684, 67.0, 72.0, 86.0, 73.0, 69.0, 77.0, 100.0], [101.54019534184823, 100.0, 97.29526671675431, 101.57776108189331, 102.44177310293013, 102.62960180315552, 87.95180722891565, 87.95180722891565, 87.95180722891565, 91.56626506024097, 86.74698795180723, 100.0, 95.18072289156626], [93.85867554568998, 100.0, 98.22419533851277, 96.04143544210136, 95.96744358120607, 94.56159822419534, 92.5, 90.0, 95.0, 90.0, 87.5, 98.75, 100.0], [107.88332676389436, 100.0, 102.01024832479307, 99.60583366180528, 103.03508080409934, 106.4249113125739, 93.75, 70.83333333333334, 70.83333333333334, 100.0, 78.125, 83.33333333333334, 85.41666666666666], [100.40189989039095, 100.0, 101.35184508586042, 102.0094994519547, 98.24625502374863, 101.38838143953232, 81.11111111111111, 80.0, 78.88888888888889, 85.55555555555556, 93.33333333333333, 100.0, 94.44444444444444], [102.25454545454546, 100.0, 101.74545454545454, 97.23636363636363, 104.80000000000001, 106.0, 94.25287356321839, 94.25287356321839, 94.25287356321839, 89.65517241379311, 90.80459770114942, 100.0, 94.25287356321839], [98.07965860597439, 100.0, 100.32005689900427, 98.15078236130867, 98.0085348506401, 98.50640113798008, 92.3913043478261, 93.47826086956522, 89.13043478260869, 95.65217391304348, 89.13043478260869, 97.82608695652173, 100.0], [94.27121102248006, 100.0, 98.76722262509064, 97.24437998549675, 95.90282813633067, 96.84554024655549, 78.0, 86.0, 81.0, 80.0, 89.0, 100.0, 98.0], [101.03846153846155, 100.0, 99.88461538461539, 100.76923076923077, 101.53846153846153, 102.11538461538461, 86.73469387755102, 84.6938775510204, 91.83673469387756, 89.79591836734694, 93.87755102040816, 100.0, 93.87755102040816], [101.63684811572136, 100.0, 100.49486105824134, 101.97944423296536, 103.1594975256947, 103.73049105443472, 92.63157894736842, 86.31578947368422, 85.26315789473684, 88.42105263157895, 87.36842105263159, 100.0, 97.89473684210527], [102.20973782771536, 100.0, 101.0112359550562, 102.62172284644195, 99.7378277153558, 100.74906367041199, 93.54838709677419, 92.47311827956989, 93.54838709677419, 96.7741935483871, 94.6236559139785, 100.0, 98.9247311827957], [108.05872756933115, 100.0, 99.64110929853182, 100.0326264274062, 106.23164763458402, 106.557911908646, 84.44444444444444, 94.44444444444444, 95.55555555555556, 96.66666666666667, 92.22222222222223, 100.0, 86.66666666666667], [103.20048309178745, 100.0, 97.52415458937197, 99.6376811594203, 101.17753623188406, 99.84903381642512, 76.0, 83.0, 84.0, 92.0, 92.0, 96.0, 100.0], [106.62891405729513, 100.0, 97.4350433044637, 96.1359093937375, 108.79413724183877, 109.26049300466354, 89.53488372093024, 91.86046511627907, 98.83720930232558, 89.53488372093024, 89.53488372093024, 98.83720930232558, 100.0], [96.3761324586067, 100.0, 99.81255857544518, 101.28084973445799, 97.62574195563887, 98.5004686035614, 91.0, 90.0, 90.0, 85.0, 89.0, 100.0, 97.0], [101.06969205834685, 100.0, 103.07941653160452, 104.73257698541329, 105.2512155591572, 105.83468395461912, 89.58333333333334, 86.45833333333334, 89.58333333333334, 87.5, 86.45833333333334, 100.0, 81.25], [95.73444515715202, 100.0, 100.86593970493907, 100.03207184092366, 102.02052597819113, 99.10198845413727, 95.1219512195 ...

# %%
outcomes = [r[0] for r in apple_formatted_data]
predictors = [r[1:] for r in apple_formatted_data]

from sklearn.cross_validation import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(predictors, outcomes, test_size=0.1)

from sklearn import linear_model
import numpy as np
def get_coefficients(predictors, outcomes):
    """
    returns a tuple of intercept and coefficients
    """
    regr = linear_model.LinearRegression()
    regr.intercept = True 
    regr.fit(predictors, outcomes)
    
    return (regr.intercept_, regr.coef_)

coefficients = get_coefficients(Xtrain, Ytrain)

print coefficients

def predict_tomorrow(coefs, today_data):
    """ 
    coefs is a tuple of the intercept and coefficients of the model fitted
    today_data is the gtrend/stock data over the same length of time in training
    """
    intercept, coefficients = coefs 
    return (np.dot(coefficients, today_data) + intercept)

import matplotlib.pyplot as plt

def visualize_fit(coefs, predictors, outcomes):
    predicted_prices = []
    for row in predictors:
        predicted_prices.append(predict_tomorrow(coefs, row))
    plt.scatter(predicted_prices, outcomes)
    correct = 0
    total = 0
    for p, o in zip(predicted_prices, outcomes):
        p = p - 100
        o = o - 100
        if (o > 0):
            correct += 1
        total += 1
    print "percent correct:", (float(correct) / float(total))
    plt.plot([-5,5],[-5,5])
    plt.show()
    return

visualize_fit(coefficients, Xtest, Ytest)
# Out:
# (-12.073811789014357, array([ 0.        ,  0.08097772, -0.00730778,  0.14190133,  0.91754249,
#         0.00166981, -0.01561961, -0.01018927,  0.02828129,  0.00145072,
#        -0.05575131,  0.03888454]))
# percent correct:
#  0.538461538462
